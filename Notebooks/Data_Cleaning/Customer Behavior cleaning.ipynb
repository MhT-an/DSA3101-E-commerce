# %% [markdown]
# **Import packages and load data**

# %%
import pandas as pd
import gc
gc.collect()
# Out:
# 0

# %%
key = {
  "type": "service_account",
  "project_id": "macro-key-426401-g6",
  "private_key_id": "c46c59283383ca6a98d22317c3b904d28706b48a",
  "private_key": "-----BEGIN PRIVATE KEY-----\\nSkDcKd1dTYz4Tx/XnS2OlZjB\n-----END PRIVATE KEY-----\n",
  "client_email": "dsa3101project@macro-key-426401-g6.iam.gserviceaccount.com",
  "client_id": "106977152441456710656",
  "auth_uri": "https://accounts.google.com/o/oauth2/auth",
  "token_uri": "https://oauth2.googleapis.com/token",
  "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
  "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/dsa3101project%40macro-key-426401-g6.iam.gserviceaccount.com",
  "universe_domain": "googleapis.com"
}

from google.cloud import bigquery
from google.oauth2 import service_account
credentials = service_account.Credentials.from_service_account_info(key)

project_id = 'macro-key-426401-g6'
client = bigquery.Client(credentials= credentials,project=project_id)

# %%
query1 = '''
SELECT
    fullVisitorId AS users,
    visitNumber,
    visitId,
    date,
    visitStartTime AS startTime,
    geoNetwork.continent AS continent,
    geoNetwork.subContinent AS subcontinent,
    geoNetwork.country AS country,
    geoNetwork.region AS region,
    totals.timeOnSite AS timeOnSite,
    totals.pageviews AS pageviews,
    totals.hits AS numHits,
    IFNULL(totals.sessionQualityDim,0) AS sessionQuality,
    IFNULL(totals.totalTransactionRevenue, 0) AS totals_revenue,
    IFNULL(totals.transactions, 0) AS transactions,
    trafficSource.medium AS medium,
    trafficSource.source AS source
FROM `bigquery-public-data.google_analytics_sample.ga_sessions_*`
WHERE
    _TABLE_SUFFIX BETWEEN '20160801' AND '20170801'
'''

df1 = client.query(query1).result().to_dataframe()

df1['startTime'] = pd.to_datetime(df1['startTime'], unit='s')
df1['date'] = pd.to_datetime(df1['date'], format='%Y%m%d')

# %%
query = """
SELECT
    fullVisitorId AS users,
    visitNumber,
    visitId,
    hits.eCommerceAction.action_type AS action,
    hits.transaction.transactionId AS transactionId,
    hits.transaction.transactionRevenue AS transactionRevenue,
    product.v2ProductCategory AS product_category,
    product.productBrand AS brand,
    product.productPrice AS price,
    IF(product.isImpression, 1, -1) AS impression,
    IF(product.isClick, 1, 0) AS click,
    product.productListName AS product_name
FROM
    `bigquery-public-data.google_analytics_sample.ga_sessions_*`,
    UNNEST(hits) AS hits,
    UNNEST(hits.product) AS product
WHERE
    _TABLE_SUFFIX BETWEEN '20160801' AND '20170801'
        """

result = client.query(query).result().to_dataframe()

# %%
result = result.set_index(['users', 'visitId'])

# %%
customer_behavior = pd.merge(df1, result, how = 'left', left_on = ['users', 'visitId'], right_index=True)

# %% [markdown]
# **Inspect and clean product_category, sessionQuality, transactions and adjust price**

# %%
customer_behavior.head()
# Out:
#                  users  visitNumber_x     visitId       date  \
# 0  7455368374932374807              1  1488851848 2017-03-06
# 0  7455368374932374807              1  1488851848 2017-03-06
# 0  7455368374932374807              1  1488851848 2017-03-06
# 0  7455368374932374807              1  1488851848 2017-03-06
# 0  7455368374932374807              1  1488851848 2017-03-06
#
#             startTime continent      subcontinent        country  \
# 0 2017-03-07 01:57:28  Americas  Northern America  United States
# 0 2017-03-07 01:57:28  Americas  Northern America  United States
# 0 2017-03-07 01:57:28  Americas  Northern America  United States
# 0 2017-03-07 01:57:28  Americas  Northern America  United States
# 0 2017-03-07 01:57:28  Americas  Northern America  United States
#
#                           region  timeOnSite  ...  visitNumber_y  action  \
# 0  not available in demo dataset        1707  ...              1       0
# 0  not available in demo dataset        1707  ...              1       0
# 0  not available in demo dataset        1707  ...              1       0
# 0  not available in demo dataset        1707  ...              1       0
# 0  not available in demo dataset        1707  ...              1       0
#
#    transactionId  transactionRevenue  \
# 0           None                <NA>
# 0           None                <NA>
# 0           None                <NA>
# 0           None                <NA>
# 0           None                <NA>
#
#                              product_category      brand     price  \
# 0                       Home/Accessories/Fun/  (not set)   8990000
# 0  Home/Apparel/Men's/Men's-Performance Wear/  (not set)  69990000
# 0     Home/Apparel/Women's/Women's-Outerwear/  (not set)  29990000
# 0                       Home/Accessories/Fun/  (not set)  11990000
# 0                  Home/Shop by Brand/Google/  (not set)  76990000
#
#    impression click product_name
# 0           1     0     Category
# 0           1     0     Category
# 0           1     0     Category
# 0           1     0     Category
# 0           1     0     Category
#
# [5 rows x 27 columns]

# %%
customer_behavior = customer_behavior.drop(customer_behavior.columns[0], axis=1)

# %%
customer_behavior.columns
# Out:
# Index(['visitNumber_x', 'visitId', 'date', 'startTime', 'continent',
#        'subcontinent', 'country', 'region', 'timeOnSite', 'pageviews',
#        'numHits', 'sessionQuality', 'totals_revenue', 'transactions', 'medium',
#        'source', 'visitNumber_y', 'action', 'transactionId',
#        'transactionRevenue', 'product_category', 'brand', 'price',
#        'impression', 'click', 'product_name'],
#       dtype='object')

# %%
customer_behavior.head()
# sessionQuality NA change to -1, transactions NA change to 0
# Out:
#    visitNumber_x     visitId       date           startTime continent  \
# 0              1  1488851848 2017-03-06 2017-03-07 01:57:28  Americas
# 0              1  1488851848 2017-03-06 2017-03-07 01:57:28  Americas
# 0              1  1488851848 2017-03-06 2017-03-07 01:57:28  Americas
# 0              1  1488851848 2017-03-06 2017-03-07 01:57:28  Americas
# 0              1  1488851848 2017-03-06 2017-03-07 01:57:28  Americas
#
#        subcontinent        country                         region  timeOnSite  \
# 0  Northern America  United States  not available in demo dataset        1707
# 0  Northern America  United States  not available in demo dataset        1707
# 0  Northern America  United States  not available in demo dataset        1707
# 0  Northern America  United States  not available in demo dataset        1707
# 0  Northern America  United States  not available in demo dataset        1707
#
#    pageviews  ...  visitNumber_y  action  transactionId  transactionRevenue  \
# 0         15  ...              1       0           None                <NA>
# 0         15  ...              1       0           None                <NA>
# 0         15  ...              1       0           None                <NA>
# 0         15  ...              1       0           None                <NA>
# 0         15  ...              1       0           None                <NA>
#
#                              product_category      brand     price impression  \
# 0                       Home/Accessories/Fun/  (not set)   8990000          1
# 0  Home/Apparel/Men's/Men's-Performance Wear/  (not set)  69990000          1
# 0     Home/Apparel/Women's/Women's-Outerwear/  (not set)  29990000          1
# 0                       Home/Accessories/Fun/  (not set)  11990000          1
# 0                  Home/Shop by Brand/Google/  (not set)  76990000          1
#
#   click  product_name
# 0     0      Category
# 0     0      Category
# 0     0      Category
# 0     0      Category
# 0     0      Category
#
# [5 rows x 26 columns]

# %%
def clean_elementary(category):
    # Remove unwanted characters and trim whitespace
    if type(category) != str:
        return ''
    category = category.replace('${escCatTitle}', '') \
                       .replace('${productitem.product.origCatName}', '') \
                       .replace('(not set)', '')
    # Remove trailing slashes
    if category.endswith('/'):
        category = category[:-1]  # Remove the last character (the slash)

    # Remove prefix 'Home/'
    if category.startswith('Home/'):
        category = category.replace('Home/', '', 1)  # Remove 'Home/' only once
    
    if category.startswith('/'):
        category = category.replace('/', '', 1)

    return category

# %%
customer_behavior['clean_intermediate'] = customer_behavior['product_category'].apply(clean_elementary)

# %%
exact_replacements = {
    "Apparel//Men's-T-Shirts": "Apparel/Men's/Men's-T-Shirts",
    'Backpacks': 'Bags/Backpacks',
    'Bottles': 'Accessories/Drinkware/Water Bottles and Tumblers',
    'Drinkware/Bottles': 'Accessories/Drinkware/Water Bottles and Tumblers',
    'Drinkware': 'Accessories/Drinkware',
    'Drinkware/Mugs and Cups': 'Accessories/Drinkware/Mugs and Cups',
    'Drinkware/Water Bottles and Tumblers': 'Accessories/Drinkware/Water Bottles and Tumblers',
    'Electronics/Accessories/Drinkware': 'Accessories/Drinkware',
    'Drinkware/Mugs': 'Accessories/Drinkware/Mugs and Cups',
    'Mugs': 'Accessories/Drinkware/Mugs and Cups',
    'Clearance Sale': 'Sale/Clearance',
    'Spring Sale!': 'Sale/Spring',
    'Fun': 'Accessories/Fun',
    'Fruit Games': 'Accessories/Fun',
    'Lifestyle/Fun': 'Accessories/Fun',
    "Men's-Outerwear": "Apparel/Men's/Men's-Outerwear",
    "Men's/Men's-Performance Wear": "Apparel/Men's/Men's-Performance Wear",
    'Mens Outerwear': "Apparel/Men's/Men's-Outerwear",
    'More Bags': 'Bags/More Bags',
    'Notebooks & Journals': 'Office/Notebooks & Journals',
    'Office/Office Other': 'Office/Other',
    'Office/Writing Instruments': 'Office/Writing',
    'Shop by Brand': 'Brands',
    'Shop by Brand/Google': 'Brands/Google',
    'Shop by Brand/Waze': 'Brands/Waze',
    'Shop by Brand/YouTube': 'Brands/YouTube',
    'Shop by Brand/Android': 'Brands/Android',
    'Google': 'Brands/Google',
    'Housewares': 'Accessories/Housewares',
    'Headgear': 'Apparel/Headgear',
    'Headwear': 'Apparel/Headwear',
    'Home': '',
    'Tumblers': 'Accessories/Drinkware/Water Bottles and Tumblers',
    'Waze': 'Brands/Waze',
    'Wearables': 'Apparel',
    "Wearables/Men's T-Shirts": "Apparel/Men's/Men's-T-Shirts",
    'Writing': 'Office/Writing',
    'YouTube': 'Brands/Youtube',
    'Android': 'Brands/Android',
}

# %%
customer_behavior['cleaned_category'] = customer_behavior['clean_intermediate'].replace(exact_replacements)

# %%
customer_behavior[['main_category', 'sub_category', 'subsub_category']] = customer_behavior['cleaned_category'].str.split('/', expand=True)

# %%
customer_behavior.drop(columns=['product_category','clean_intermediate', 'cleaned_category'], inplace=True)

# %%
columns_to_fill = ['main_category', 'sub_category', 'subsub_category']

customer_behavior[columns_to_fill] = customer_behavior[columns_to_fill].fillna('Other')

# %%
customer_behavior['totals_revenue'] = customer_behavior['totals_revenue'] / 1e6
customer_behavior['transactionRevenue'] = customer_behavior['transactionRevenue'] / 1e6
customer_behavior['price'] = customer_behavior['price'] / 1e6

# %%
customer_behavior.head()
# Out:
#    visitNumber_x     visitId       date           startTime continent  \
# 0              1  1488851848 2017-03-06 2017-03-07 01:57:28  Americas
# 0              1  1488851848 2017-03-06 2017-03-07 01:57:28  Americas
# 0              1  1488851848 2017-03-06 2017-03-07 01:57:28  Americas
# 0              1  1488851848 2017-03-06 2017-03-07 01:57:28  Americas
# 0              1  1488851848 2017-03-06 2017-03-07 01:57:28  Americas
#
#        subcontinent        country                         region  timeOnSite  \
# 0  Northern America  United States  not available in demo dataset        1707
# 0  Northern America  United States  not available in demo dataset        1707
# 0  Northern America  United States  not available in demo dataset        1707
# 0  Northern America  United States  not available in demo dataset        1707
# 0  Northern America  United States  not available in demo dataset        1707
#
#    pageviews  ...  transactionId  transactionRevenue      brand  price  \
# 0         15  ...           None                <NA>  (not set)   8.99
# 0         15  ...           None                <NA>  (not set)  69.99
# 0         15  ...           None                <NA>  (not set)  29.99
# 0         15  ...           None                <NA>  (not set)  11.99
# 0         15  ...           None                <NA>  (not set)  76.99
#
#   impression click  product_name main_category sub_category  \
# 0          1     0      Category   Accessories          Fun
# 0          1     0      Category       Apparel        Men's
# 0          1     0      Category       Apparel      Women's
# 0          1     0      Category   Accessories          Fun
# 0          1     0      Category        Brands       Google
#
#           subsub_category
# 0                   Other
# 0  Men's-Performance Wear
# 0       Women's-Outerwear
# 0                   Other
# 0                   Other
#
# [5 rows x 28 columns]
